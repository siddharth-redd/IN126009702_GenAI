# %% [markdown]
# <h2>Install Libraries</h2>

# %%
# !pip install transformers torch
# Out:
# Collecting transformers
#   Downloading transformers-5.4.0-py3-none-any.whl.metadata (32 kB)
# Collecting torch
#   Downloading torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2026.3.32)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer (from transformers)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from transformers) (4.67.3)
# Collecting filelock (from torch)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from torch) (4.15.0)
# Collecting setuptools<82 (from torch)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.4.2-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: click>=8.2.1 in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from typer->transformers) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->transformers)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\siddharth\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->transformers)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from rich>=12.3.0->typer->transformers) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading transformers-5.4.0-py3-none-any.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.1 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/10.1 MB 10.8 MB/s eta 0:00:01
#    ------------------------ --------------- 6.3/10.1 MB 12.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/10.1 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 11.4 MB/s eta 0:00:00
# Downloading torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
#    ---------------------------------------- 0.0/114.6 MB ? eta -:--:--
#    - -------------------------------------- 3.9/114.6 MB 20.5 MB/s eta 0:00:06
#    -- ------------------------------------- 8.4/114.6 MB 20.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 12.1/114.6 MB 19.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 14.7/114.6 MB 17.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 16.0/114.6 MB 15.7 MB/s eta 0:00:07
#    ------ --------------------------------- 17.3/114.6 MB 14.2 MB/s eta 0:00:07
#    ------ --------------------------------- 18.9/114.6 MB 12.9 MB/s eta 0:00:08
#    ------- -------------------------------- 20.4/114.6 MB 12.2 MB/s eta 0:00:08
#    ------- -------------------------------- 21.8/114.6 MB 11.7 MB/s eta 0:00:08
#    -------- ------------------------------- 23.3/114.6 MB 11.1 MB/s eta 0:00:09
#    -------- ------------------------------- 24.9/114.6 MB 10.8 MB/s eta 0:00:09
#    --------- ------------------------------ 26.5/114.6 MB 10.5 MB/s eta 0:00:09
#    --------- ------------------------------ 28.3/114.6 MB 10.3 MB/s eta 0:00:09
#    ---------- ----------------------------- 29.6/114.6 MB 10.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 31.5/114.6 MB 9.9 MB/s eta 0:00:09
#    ----------- ---------------------------- 33.0/114.6 MB 9.9 MB/s eta 0:00:09
#    ------------ --------------------------- 34.6/114.6 MB 9.7 MB/s eta 0:00:09
#    ------------ --------------------------- 35.9/114.6 MB 9.5 MB/s eta 0:00:09
#    ------------ --------------------------- 37.2/114.6 MB 9.3 MB/s eta 0:00:09
#    ------------- -------------------------- 38.5/114.6 MB 9.1 MB/s eta 0:00:09
#    -------------- ------------------------- 40.4/114.6 MB 9.1 MB/s eta 0:00:09
#    -------------- ------------------------- 42.2/114.6 MB 9.1 MB/s eta 0:00:08
#    --------------- ------------------------ 44.0/114.6 MB 9.0 MB/s eta 0:00:08
#    --------------- ------------------------ 45.6/114.6 MB 9.0 MB/s eta 0:00:08
#    ---------------- ----------------------- 47.4/114.6 MB 9.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 49.0/114.6 MB 8.9 MB/s eta 0:00:08
#    ----------------- ---------------------- 50.9/114.6 MB 8.9 MB/s eta 0:00:08
#    ------------------ --------------------- 52.4/114.6 MB 8.8 MB/s eta 0:00:08
#    ------------------ --------------------- 54.3/114.6 MB 8.8 MB/s eta 0:00:07
#    ------------------- -------------------- 56.1/114.6 MB 8.8 MB/s eta 0:00:07
#    -------------------- ------------------- 57.9/114.6 MB 8.8 MB/s eta 0:00:07
#    -------------------- ------------------- 59.2/114.6 MB 8.8 MB/s eta 0:00:07
#    --------------------- ------------------ 61.1/114.6 MB 8.7 MB/s eta 0:00:07
#    --------------------- ------------------ 62.9/114.6 MB 8.7 MB/s eta 0:00:06
#    ---------------------- ----------------- 64.7/114.6 MB 8.7 MB/s eta 0:00:06
#    ----------------------- ---------------- 66.6/114.6 MB 8.7 MB/s eta 0:00:06
#    ----------------------- ---------------- 68.4/114.6 MB 8.7 MB/s eta 0:00:06
#    ------------------------ --------------- 70.3/114.6 MB 8.7 MB/s eta 0:00:06
#    ------------------------- -------------- 72.4/114.6 MB 8.7 MB/s eta 0:00:05
#    ------------------------- -------------- 73.9/114.6 MB 8.7 MB/s eta 0:00:05
#    -------------------------- ------------- 75.8/114.6 MB 8.7 MB/s eta 0:00:05
#    --------------------------- ------------ 77.3/114.6 MB 8.7 MB/s eta 0:00:05
#    --------------------------- ------------ 79.2/114.6 MB 8.7 MB/s eta 0:00:05
#    ---------------------------- ----------- 81.0/114.6 MB 8.6 MB/s eta 0:00:04
#    ---------------------------- ----------- 82.8/114.6 MB 8.6 MB/s eta 0:00:04
#    ----------------------------- ---------- 84.1/114.6 MB 8.6 MB/s eta 0:00:04
#    ------------------------------ --------- 86.0/114.6 MB 8.6 MB/s eta 0:00:04
#    ------------------------------ --------- 87.8/114.6 MB 8.6 MB/s eta 0:00:04
#    ------------------------------- -------- 89.7/114.6 MB 8.6 MB/s eta 0:00:03
#    ------------------------------- -------- 91.5/114.6 MB 8.6 MB/s eta 0:00:03
#    -------------------------------- ------- 93.3/114.6 MB 8.6 MB/s eta 0:00:03
#    --------------------------------- ------ 95.2/114.6 MB 8.6 MB/s eta 0:00:03
#    --------------------------------- ------ 96.5/114.6 MB 8.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 98.3/114.6 MB 8.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 100.4/114.6 MB 8.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 102.0/114.6 MB 8.5 MB/s eta 0:00:02
#    ------------------------------------ --- 104.1/114.6 MB 8.5 MB/s eta 0:00:02
#    ------------------------------------- -- 106.2/114.6 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------- -- 108.5/114.6 MB 8.6 MB/s eta 0:00:01
#    -------------------------------------- - 110.9/114.6 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  113.0/114.6 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  114.3/114.6 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  114.3/114.6 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  114.3/114.6 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 114.6/114.6 MB 8.4 MB/s eta 0:00:00
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading huggingface_hub-1.8.0-py3-none-any.whl (625 kB)
#    ---------------------------------------- 0.0/625.2 kB ? eta -:--:--
#    --------------------------------------- 625.2/625.2 kB 15.6 MB/s eta 0:00:00
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------------- ---- 1.8/2.1 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 8.6 MB/s eta 0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 9.0 MB/s eta 0:00:00
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------------------ --------- 2.1/2.7 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 9.4 MB/s eta 0:00:00
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading hf_xet-1.4.2-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ---------------------- ----------------- 2.1/3.7 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 10.7 MB/s eta 0:00:00
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mpmath, sympy, shellingham, setuptools, safetensors, networkx, mdurl, hf-xet, fsspec, filelock, torch, markdown-it-py, rich, typer, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.0
#     Uninstalling setuptools-82.0.0:
#       Successfully uninstalled setuptools-82.0.0
# Successfully installed filelock-3.25.2 fsspec-2026.3.0 hf-xet-1.4.2 huggingface-hub-1.8.0 markdown-it-py-4.0.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.6.1 rich-14.3.3 safetensors-0.7.0 setuptools-81.0.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.11.0 transformers-5.4.0 typer-0.24.1
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <h2>Load Model</h2>

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "google/flan-t5-base"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# Loading weights: 100%|██████████████████████████████████████████████████████████████████████████| 282/282 [00:00<00:00, 8893.52it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.

# %% [markdown]
# <h2>Chatbot Function</h2>

# %%
def chatbot():
    print("Chatbot: Hello! I am your AI assistant. How can I help you today?\n")

    while True:
        user_input = input("You: ")

        if user_input.lower() in ["exit", "quit"]:
            print("Chatbot: Goodbye!")
            break

        input_text = f"""
        You are a helpful AI assistant.
        Answer the question clearly and correctly.

        Question: {user_input}
        Answer:
        """

        inputs = tokenizer(input_text, return_tensors="pt", truncation=True)

        outputs = model.generate(
            **inputs,
            max_new_tokens=80,
            temperature=0.3,   
            do_sample=True
        )

        response = tokenizer.decode(outputs[0], skip_special_tokens=True)

        print("Chatbot:", response.strip())

# %%
chatbot()
# Out:
# Chatbot: Hello! I am your AI assistant. How can I help you today?
# You:  Hello
# Chatbot: Hello
# You:  What is Artificial Intelligence
# Chatbot: a computer program
# You:  Who created python
# Chatbot: the physicist
# You:  Thank you
# Chatbot: You're welcome.
# You:  exit
# Chatbot: Goodbye!
